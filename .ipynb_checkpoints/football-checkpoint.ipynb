# %%
import pandas as pd
plays = pd.read_csv("teams.csv")
plays
# Out:
#      season  teamId abbr   cityState             fullName      nick  \
# 0      1999     200  ATL     Atlanta      Atlanta Falcons   Falcons
# 1      1999     325  BAL   Baltimore     Baltimore Ravens    Ravens
# 2      1999     610  BUF     Buffalo        Buffalo Bills     Bills
# 3      1999     750  CAR    Carolina    Carolina Panthers  Panthers
# 4      1999     810  CHI     Chicago        Chicago Bears     Bears
# ..      ...     ...  ...         ...                  ...       ...
# 195    2012    5110  WAS  Washington  Washington Redskins  Redskins
# 196    2013     200  ATL     Atlanta      Atlanta Falcons   Falcons
# 197    2013     325  BAL   Baltimore     Baltimore Ravens    Ravens
# 198    2013     610  BUF     Buffalo        Buffalo Bills     Bills
# 199    2013     750  CAR    Carolina    Carolina Panthers  Panthers
#
#     conferenceAbbr divisionAbbr
# 0              NFC          NCW
# 1              AFC          ACC
# 2              AFC          ACE
# ...
